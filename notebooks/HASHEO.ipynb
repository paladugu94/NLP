# %%
import pandas as pd
import numpy as np

# %%
dashboard = "..\\..\\..\\data_nps\\dashboard\\"
hasheado = pd.read_csv(dashboard+"nps_actualizado2020.csv",sep=',',encoding = 'UTF-8')
# Out:
# C:\ProgramData\Anaconda3\envs\topic_modelling\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (70) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 CREATION_DATE RESPONSE_DATE CURRENT_STATUS  \
# 0           0    2018-12-05    2019-01-02       Resolved
# 1           1    2018-12-05    2019-01-03              0
#
#                               ALL_LOG_NOTES_COMBINED  \
# 0  [2019-01-02 10:46:48] Alert Created: Detractor...
# 1                                                  0
#
#   ALERT_STATUS_CHANGED_TIME       CASE_OWNER FEEDBACK_CALL_DATE  \
# 0        21/5/2019 06:44:04  vanni gorostiza           3/1/2019
# 1                         0                0                  0
#
#    FEEDBACK_CALL_TIME FEEDBACK_CALL_OUTCOME  ... motivos  atributos detected  \
# 0  1/12/2019 08:30:00         Not reachable  ...      []         []    False
# ...

# %%
hasheado[hasheado["detected"]==True].head()
# Out:
#    Unnamed: 0 CREATION_DATE RESPONSE_DATE CURRENT_STATUS  \
# 2           2    2018-12-06    2019-01-04         Closed
# 3           3    2018-12-06    2019-01-01              0
# 4           4    2018-12-10    2019-01-07         Closed
# 5           5    2018-12-11    2019-01-01         Closed
# 7           7    2018-12-12    2019-01-10         Closed
#
#                               ALL_LOG_NOTES_COMBINED  \
# 2  [2019-01-04 07:35:23] Alert Created: Promoter ...
# 3                                                  0
# 4  [2019-01-06 21:20:29] Alert Created: Detractor...
# 5  [2019-01-01 07:53:24] Alert Created: Promoter ...
# 7  [2019-01-10 04:07:26] Alert Created: Detractor...
#
#   ALERT_STATUS_CHANGED_TIME         CASE_OWNER FEEDBACK_CALL_DATE  \
# 2         4/1/2019 07:35:25                  0                  0
# 3                         0                  0                  0
# 4         7/1/2019 09:01:30            ferraro           7/1/2019
# ...

# %%
columnas = list(hasheado.columns)
columnas_hashear = ['FIRST_NAME', 'LAST_NAME',  'DOCUMENT_TYPE','DOCUMENT_NUMBER', 'BEST_PHONE', 'BEST_CELLPHONE', 'PRINCIPAL_ADDRESS','EMAIL']

# %%
filtro = [items for items in columnas if items not in columnas_hashear]

# %%
hasheado_df = hasheado[filtro]

# %%
hasheado_df.shape
# Out:
# (119815, 200)

# %%
hasheado.shape
# Out:
# (119815, 208)

# %%
hasheado.to_csv(dashboard+"nps_actualizado2021.csv", header = True,sep=';')

# %%
sample_completo =hasheado[0:1000]

# %%
sample_completo.to_csv(dashboard+"sample_completo.csv", header = True,sep=';')
